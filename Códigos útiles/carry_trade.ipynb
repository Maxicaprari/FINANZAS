# %%
import pandas as pd
import requests
from datetime import date, timedelta
import matplotlib.pyplot as plt

# %%
# %%time

tickers = {
    "S16A5": date(2025, 4, 16),
    "S28A5": date(2025, 4, 28),
    "S16Y5": date(2025, 5, 16),
    "S30Y5": date(2025, 5, 30),
    "S18J5": date(2025, 6, 18),
    "S30J5": date(2025, 6, 30),
    "S31L5": date(2025, 7, 31),
    "S15G5": date(2025, 8, 15),
    "S29G5": date(2025, 8, 29),
    "S12S5": date(2025, 9, 12),
    "S30S5": date(2025, 9, 30),
    "T17O5": date(2025, 10, 15),
    "S31O5": date(2025, 10, 31),
    "S10N5": date(2025, 11, 10),
    "S28N5": date(2025, 11, 28),
    "T15D5": date(2025, 12, 15),
    "T30E6": date(2026, 1, 30),
    "T13F6": date(2026, 2, 13),
    "T30J6": date(2026, 6, 30),
    # "TO26":  date(2026, 10, 17),
    "T15E7": date(2027, 1, 15),
    "TTM26": date(2026, 3, 16),
    "TTJ26": date(2026, 6, 30),
    "TTS26": date(2026, 9, 15),
    "TTD26": date(2026, 12, 15),


}

payoff = {
    "S16A5": 131.211,
    "S28A5": 130.813,
    "S16Y5": 136.861,
    "S30Y5": 136.331,
    "S18J5": 147.695,
    "S30J5": 146.607,
    "S31L5": 147.74,
    "S15G5": 146.794,
    "S29G5": 157.7,
    "S12S5": 158.977,
    "S30S5": 159.734,
    "T17O5": 158.872,
    "S31O5": 132.821,
    "S10N5": 122.254,
    "S28N5": 123.561,
    "T15D5": 170.838,
    "T30E6": 142.222,
    "T13F6": 144.966,
    "T30J6": 144.896,
    # "TO26": 123.25, # Habria que calcular aparte la reinversion de cupones
    "T15E7": 160.777,
    "TTM26": 135.238,
    "TTJ26": 144.629,
    "TTS26": 152.096,
    "TTD26": 161.144,
}


# para los duales esta considerado solo la tasa fija, se puede agregar proyeccion de TAMAR c/API del BCRA

meps = requests.get('https://data912.com/live/mep').json()
notes = requests.get('https://data912.com/live/arg_notes').json()
bonds = requests.get('https://data912.com/live/arg_bonds').json()
mep = pd.DataFrame(meps).close.median()
df = pd.DataFrame(notes+bonds)
# Out:
# CPU times: user 49.7 ms, sys: 7.87 ms, total: 57.6 ms
# Wall time: 1.75 s

# %%
df.head()
# Out:
#   symbol      q_bid   px_bid   px_ask      q_ask           v   q_op        c  \
# 0  BB2Y5  2500000.0  123.500  158.250     7496.0     51065.0   53.0  161.250
# 1  BNA6D     1146.0  101.300  101.999      991.0      1441.0    9.0  101.999
# 2  S10N5   463914.0  104.067  104.398  8283514.0   6224047.0  103.0  104.398
# 3  S12S5   312310.0  142.301  143.400  4320409.0  11042404.0   59.0  143.400
# 4  S15G5   197106.0  134.442  134.449  3925934.0  44261803.0  100.0  134.449
#
#    pct_change
# 0       -3.44
# 1        0.04
# 2        0.62
# 3        0.98
# 4        0.37

# %%
carry = df.loc[df.symbol.isin(tickers.keys())].set_index('symbol')
carry['bond_price'] = carry['c'].round(2)
carry['payoff'] = carry.index.map(payoff)
carry['expiration'] = carry.index.map(tickers)
carry['days_to_exp'] = (carry.expiration - date.today()).apply(lambda x: x.days)
carry['tna'] = ((carry['payoff'] / carry['c']) - 1) / carry['days_to_exp'] * 365
carry['tea'] = ((carry['payoff'] / carry['c'])) ** (365/carry['days_to_exp']) - 1
carry['tem'] = ((carry['payoff'] / carry['c'])) ** (1/(carry['days_to_exp']/30)) - 1
carry['tem_bid'] = ((carry['payoff'] / carry['px_bid'])) ** (1/(carry['days_to_exp']/30)) - 1
carry['tem_ask'] = ((carry['payoff'] / carry['px_ask'])) ** (1/(carry['days_to_exp']/30)) - 1
carry['finish_worst'] = (1400 * 1.01**(carry['days_to_exp']/30)).round().astype(int)
for price in [1000,1100, 1200, 1300,  1400]:
    carry[f'carry_{price}'] = (carry['payoff'] / carry['c']) * mep/price - 1
carry['carry_worst'] = (carry['payoff'] / carry['c']) * mep/carry['finish_worst'] - 1
carry = carry.sort_values('days_to_exp')

carry[['bond_price', 'days_to_exp'] + list(carry.columns[-7:])].style \
    .background_gradient(subset=carry.columns[-6:], cmap='Blues', axis=None) \
    .format({**{col: "{:.1%}" for col in carry.columns[-6:]}, 'bond_price': "{:.2f}"})
# Out:
# <style type="text/css">
# #T_b2220_row0_col3, #T_b2220_row7_col4, #T_b2220_row18_col7 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_b2220_row0_col4, #T_b2220_row6_col5, #T_b2220_row16_col7 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_b2220_row0_col5, #T_b2220_row5_col6 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_b2220_row0_col6 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_b2220_row0_col7, #T_b2220_row1_col8 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_b2220_row0_col8 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_b2220_row1_col3 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_b2220_row1_col4, #T_b2220_row20_col8 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_b2220_row1_col5, #T_b2220_row7_col6 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_b2220_row1_col6, #T_b2220_row6_col7, #T_b2220_row11_col8 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_b2220_row1_col7, #T_b2220_row2_col8, #T_b2220_row3_col8 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_b2220_row2_col3 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_b2220_row2_col4, #T_b2220_row8_col5 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_b2220_row2_col5 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_b2220_row2_col6 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_b2220_row2_col7, #T_b2220_row4_col8 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_b2220_row3_col3 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_b2220_row3_col4 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_b2220_row3_col5, #T_b2220_row8_col6 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_b2220_row3_col6 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_b2220_row3_col7 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_b2220_row4_col3, #T_b2220_row19_col7 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_b2220_row4_col4 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_b2220_row4_col5, #T_b2220_row9_col6, #T_b2220_row10_col6 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_b2220_row4_col6, #T_b2220_row9_col7, #T_b2220_row16_col8 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_b2220_row4_col7 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_b2220_row5_col3 {
#   background-color: #8cc0dd;
#   color: #000000;
# }
# #T_b2220_row5_col4 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_b2220_row5_col5, #T_b2220_row12_col6 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_b2220_row5_col7, #T_b2220_row9_col8 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_b2220_row5_col8, #T_b2220_row6_col8 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_b2220_row6_col3 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_b2220_row6_col4 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_b2220_row6_col6, #T_b2220_row12_col7 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_b2220_row7_col3 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_b2220_row7_col5, #T_b2220_row13_col6 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_b2220_row7_col7 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_b2220_row7_col8 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_b2220_row8_col3, #T_b2220_row20_col7 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_b2220_row8_col4 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_b2220_row8_col7 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_b2220_row8_col8 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_b2220_row9_col3 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_b2220_row9_col4, #T_b2220_row10_col4 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_b2220_row9_col5, #T_b2220_row10_col5 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_b2220_row10_col3, #T_b2220_row15_col4 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_b2220_row10_col7, #T_b2220_row15_col8 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_b2220_row10_col8 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_b2220_row11_col3, #T_b2220_row17_col5 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_b2220_row11_col4 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_b2220_row11_col5 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_b2220_row11_col6 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_b2220_row11_col7 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_b2220_row12_col3 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_b2220_row12_col4 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_b2220_row12_col5, #T_b2220_row16_col6 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_b2220_row12_col8 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_b2220_row13_col3 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_b2220_row13_col4 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_b2220_row13_col5, #T_b2220_row17_col7 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_b2220_row13_col7 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_b2220_row13_col8 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_b2220_row14_col3 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_b2220_row14_col4 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_b2220_row14_col5 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_b2220_row14_col6 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_b2220_row14_col7 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_b2220_row14_col8 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_b2220_row15_col3 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_b2220_row15_col5 {
#   background-color: #9ac8e0;
#   color: #000000;
# }
# #T_b2220_row15_col6 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_b2220_row15_col7 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_b2220_row16_col3 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_b2220_row16_col4 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_b2220_row16_col5 {
#   background-color: #95c5df;
#   color: #000000;
# }
# #T_b2220_row17_col3 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_b2220_row17_col4 {
#   background-color: #4191c6;
#   color: #f1f1f1;
# }
# #T_b2220_row17_col6 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_b2220_row17_col8 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_b2220_row18_col3 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_b2220_row18_col4 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_b2220_row18_col5 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_b2220_row18_col6 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_b2220_row18_col8 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_b2220_row19_col3 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_b2220_row19_col4 {
#   background-color: #2a7ab9;
#   color: #f1f1f1;
# }
# #T_b2220_row19_col5 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_b2220_row19_col6, #T_b2220_row21_col7 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_b2220_row19_col8 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_b2220_row20_col3 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_b2220_row20_col4 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_b2220_row20_col5 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_b2220_row20_col6 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_b2220_row21_col3 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_b2220_row21_col4 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_b2220_row21_col5 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_b2220_row21_col6 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_b2220_row21_col8 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# </style>
# <table id="T_b2220" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b2220_level0_col0" class="col_heading level0 col0" >bond_price</th>
#       <th id="T_b2220_level0_col1" class="col_heading level0 col1" >days_to_exp</th>
#       <th id="T_b2220_level0_col2" class="col_heading level0 col2" >finish_worst</th

# %%
vmax = carry[carry.columns[-6:]].max().max()
vmin = carry[carry.columns[-6:]].min().min()
lim = max(abs(vmin), abs(vmax)) * 0.3

carry[['bond_price', 'days_to_exp', 'tem'] + list(carry.columns[-7:])].style \
    .background_gradient(subset=carry.columns[-6:], cmap='RdYlGn', axis=None, vmin=-lim, vmax=lim) \
    .format({**{col: "{:.1%}" for col in carry.columns[-6:]}, 'bond_price': "{:.2f}", 'tem': "{:.2%}"})
# Out:
# <style type="text/css">
# #T_1a467_row0_col4, #T_1a467_row18_col8 {
#   background-color: #48ae5c;
#   color: #f1f1f1;
# }
# #T_1a467_row0_col5, #T_1a467_row6_col6, #T_1a467_row16_col8 {
#   background-color: #c9e881;
#   color: #000000;
# }
# #T_1a467_row0_col6 {
#   background-color: #fff3ac;
#   color: #000000;
# }
# #T_1a467_row0_col7, #T_1a467_row10_col9 {
#   background-color: #fdb768;
#   color: #000000;
# }
# #T_1a467_row0_col8, #T_1a467_row1_col9 {
#   background-color: #f36b42;
#   color: #f1f1f1;
# }
# #T_1a467_row0_col9 {
#   background-color: #f16640;
#   color: #f1f1f1;
# }
# #T_1a467_row1_col4 {
#   background-color: #36a657;
#   color: #f1f1f1;
# }
# #T_1a467_row1_col5, #T_1a467_row20_col9 {
#   background-color: #bbe278;
#   color: #000000;
# }
# #T_1a467_row1_col6 {
#   background-color: #fffbb8;
#   color: #000000;
# }
# #T_1a467_row1_col7, #T_1a467_row11_col9 {
#   background-color: #fdc171;
#   color: #000000;
# }
# #T_1a467_row1_col8, #T_1a467_row2_col9 {
#   background-color: #f57547;
#   color: #f1f1f1;
# }
# #T_1a467_row2_col4 {
#   background-color: #1b9950;
#   color: #f1f1f1;
# }
# #T_1a467_row2_col5 {
#   background-color: #abdb6d;
#   color: #000000;
# }
# #T_1a467_row2_col6 {
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_1a467_row2_col7, #T_1a467_row13_col9 {
#   background-color: #fece7c;
#   color: #000000;
# }
# #T_1a467_row2_col8, #T_1a467_row4_col9 {
#   background-color: #f8864f;
#   color: #f1f1f1;
# }
# #T_1a467_row3_col4 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_1a467_row3_col5 {
#   background-color: #a5d86a;
#   color: #000000;
# }
# #T_1a467_row3_col6, #T_1a467_row8_col7 {
#   background-color: #f5fbb2;
#   color: #000000;
# }
# #T_1a467_row3_col7 {
#   background-color: #fed481;
#   color: #000000;
# }
# #T_1a467_row3_col8 {
#   background-color: #f98e52;
#   color: #f1f1f1;
# }
# #T_1a467_row3_col9 {
#   background-color: #f57748;
#   color: #f1f1f1;
# }
# #T_1a467_row4_col4 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_1a467_row4_col5 {
#   background-color: #84ca66;
#   color: #000000;
# }
# #T_1a467_row4_col6, #T_1a467_row14_col8 {
#   background-color: #e3f399;
#   color: #000000;
# }
# #T_1a467_row4_col7 {
#   background-color: #fee695;
#   color: #000000;
# }
# #T_1a467_row4_col8 {
#   background-color: #fca85e;
#   color: #000000;
# }
# #T_1a467_row5_col4, #T_1a467_row6_col4, #T_1a467_row7_col4, #T_1a467_row8_col4, #T_1a467_row9_col4, #T_1a467_row10_col4, #T_1a467_row11_col4, #T_1a467_row12_col4, #T_1a467_row13_col4, #T_1a467_row13_col5, #T_1a467_row14_col4, #T_1a467_row14_col5, #T_1a467_row15_col4, #T_1a467_row15_col5, #T_1a467_row16_col4, #T_1a467_row16_col5, #T_1a467_row17_col4, #T_1a467_row17_col5, #T_1a467_row17_col6, #T_1a467_row18_col4, #T_1a467_row18_col5, #T_1a467_row18_col6, #T_1a467_row18_col7, #T_1a467_row19_col4, #T_1a467_row19_col5, #T_1a467_row19_col6, #T_1a467_row19_col7, #T_1a467_row20_col4, #T_1a467_row20_col5, #T_1a467_row20_col6, #T_1a467_row20_col7, #T_1a467_row20_col8, #T_1a467_row21_col4, #T_1a467_row21_col5, #T_1a467_row21_col6, #T_1a467_row21_col7, #T_1a467_row21_col8 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_1a467_row5_col5 {
#   background-color: #66bd63;
#   color: #f1f1f1;
# }
# #T_1a467_row5_col6 {
#   background-color: #d1ec86;
#   color: #000000;
# }
# #T_1a467_row5_col7 {
#   background-color: #fff2aa;
#   color: #000000;
# }
# #T_1a467_row5_col8, #T_1a467_row9_col9 {
#   background-color: #fdbb6c;
#   color: #000000;
# }
# #T_1a467_row5_col9 {
#   background-color: #fa9857;
#   color: #000000;
# }
# #T_1a467_row6_col5 {
#   background-color: #57b65f;
#   color: #f1f1f1;
# }
# #T_1a467_row6_col7, #T_1a467_row12_col8 {
#   background-color: #fff7b2;
#   color: #000000;
# }
# #T_1a467_row6_col8 {
#   background-color: #fdc372;
#   color: #000000;
# }
# #T_1a467_row6_col9 {
#   background-color: #fa9b58;
#   color: #000000;
# }
# #T_1a467_row7_col5 {
#   background-color: #4bb05c;
#   color: #f1f1f1;
# }
# #T_1a467_row7_col6 {
#   background-color: #c1e57b;
#   color: #000000;
# }
# #T_1a467_row7_col7 {
#   background-color: #fffcba;
#   color: #000000;
# }
# #T_1a467_row7_col8 {
#   background-color: #fec877;
#   color: #000000;
# }
# #T_1a467_row7_col9 {
#   background-color: #fb9d59;
#   color: #000000;
# }
# #T_1a467_row8_col5 {
#   background-color: #2aa054;
#   color: #f1f1f1;
# }
# #T_1a467_row8_col6 {
#   background-color: #addc6f;
#   color: #000000;
# }
# #T_1a467_row8_col8 {
#   background-color: #feda86;
#   color: #000000;
# }
# #T_1a467_row8_col9 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_1a467_row9_col5, #T_1a467_row10_col5 {
#   background-color: #128a49;
#   color: #f1f1f1;
# }
# #T_1a467_row9_col6 {
#   background-color: #91d068;
#   color: #000000;
# }
# #T_1a467_row9_col7, #T_1a467_row10_col7 {
#   background-color: #e5f49b;
#   color: #000000;
# }
# #T_1a467_row9_col8, #T_1a467_row10_col8, #T_1a467_row15_col9 {
#   background-color: #fee999;
#   color: #000000;
# }
# #T_1a467_row10_col6 {
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_1a467_row11_col5 {
#   background-color: #0a7b41;
#   color: #f1f1f1;
# }
# #T_1a467_row11_col6 {
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_1a467_row11_col7 {
#   background-color: #daf08d;
#   color: #000000;
# }
# #T_1a467_row11_col8 {
#   background-color: #fff0a6;
#   color: #000000;
# }
# #T_1a467_row12_col5 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_1a467_row12_col6, #T_1a467_row16_col7 {
#   background-color: #6ec064;
#   color: #000000;
# }
# #T_1a467_row12_col7 {
#   background-color: #cfeb85;
#   color: #000000;
# }
# #T_1a467_row12_col9 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_1a467_row13_col6, #T_1a467_row17_col8 {
#   background-color: #54b45f;
#   color: #f1f1f1;
# }
# #T_1a467_row13_col7 {
#   background-color: #bfe47a;
#   color: #000000;
# }
# #T_1a467_row13_col8 {
#   background-color: #feffbe;
#   color: #000000;
# }
# #T_1a467_row14_col6 {
#   background-color: #18954f;
#   color: #f1f1f1;
# }
# #T_1a467_row14_col7 {
#   background-color: #96d268;
#   color: #000000;
# }
# #T_1a467_row14_col9 {
#   background-color: #fee08b;
#   color: #000000;
# }
# #T_1a467_row15_col6 {
#   background-color: #0d8044;
#   color: #f1f1f1;
# }
# #T_1a467_row15_col7 {
#   background-color: #7ac665;
#   color: #000000;
# }
# #T_1a467_row15_col8 {
#   background-color: #d3ec87;
#   color: #000000;
# }
# #T_1a467_row16_col6 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_1a467_row16_col9 {
#   background-color: #fee797;
#   color: #000000;
# }
# #T_1a467_row17_col7 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_1a467_row17_col9 {
#   background-color: #f4fab0;
#   color: #000000;
# }
# #T_1a467_row18_col9 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_1a467_row19_col8 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_1a467_row19_col9 {
#   background-color: #d9ef8b;
#   color: #000000;
# }
# #T_1a467_row21_col9 {
#   background-color: #b5df74;
#   color: #000000;
# }
# </style>
# <table id="T_1a467" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1a467_level0_col0" class="col_heading level0 col0" >bond_price</th>
#       <th id="T_1a467_level0_col1" class="col_heading level0 col1" >days_to_exp</th>
#       <th id="T_1a467_level0_col2" class="col_heading level0 col2" >tem</th>
#       <th id="T_1a467_level0_col3" class="col_heading level0 col3" >finish_worst</th>
#       <th id="T_1a467_level0_col4" class="col_heading level0 col4" >carry_1000</th>
#       <th id="T_1a467_level0_col5" class="col_heading level0 col5" >carry_1100</th>
#       <th id="T_1a467_level0_col6" class="col_heading level0 col6" >carry_1200</th>
#       <th id="T_1a467_level0_col7" class="col_heading level0 col7" >carry_1300</th>
#       <th id="T_1a467_level0_col8" class="col_heading level0 col8" >carry_1400</th>
#       <th id="T_1a467_level0_col9" class="col_heading level0 col9" >carry_worst</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >symbol</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbod

# %%
carry['MEP_BREAKEVEN'] = mep * ((carry['payoff'] / carry['c']))

plt.style.use('dark_background')
plt.rcParams.update({'font.size': 6})

fig, ax = plt.subplots(figsize=(10,6), dpi=250, facecolor='black')

ax.plot(carry['finish_worst'], color='orange', label='Banda superior')
ax.plot(carry['MEP_BREAKEVEN'], color='white', lw=0, marker='o', markersize=5, label='MEP Breakeven')

for i, txt in enumerate(carry.index):
    y1 = carry['finish_worst'].iloc[i]
    y2 = carry['MEP_BREAKEVEN'].iloc[i]

    ax.annotate(txt, (i, y1), textcoords="offset points", xytext=(0, 5), ha='center', fontsize=5, color='orange')
    ax.annotate(txt, (i, y2), textcoords="offset points", xytext=(0, -10), ha='center', fontsize=5, color='white')
    ax.annotate(f'$ {y2:.0f}', (i, y2), textcoords="offset points", xytext=(0, -15), ha='center', fontsize=4, color='white')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.grid(alpha=0.2)

ax.legend(frameon=False, ncol=2, fontsize=10, loc='upper center')
plt.show()

# %%
# Simulacion rendimiento en pesos, estrategia de salida antes por compresion de tasa

CPI_EST = 0.01 # tasa estimada TEM general (Si todo sale bien esa tasa va a ir convergiendo a la de inflacion mensual)
EST_DATE = date(2025, 10, 15) # Fecha de salida con esa TEM (Fecha estimada pra desarmar)

carry_exit = df.loc[df.symbol.isin(tickers.keys())].set_index('symbol')
carry_exit['days_in'] = (EST_DATE - date.today()).days
carry_exit['payoff'] = carry_exit.index.map(payoff)
carry_exit['expiration'] = carry_exit.index.map(tickers)
carry_exit['days_to_exp'] = (carry_exit.expiration - EST_DATE).apply(lambda x: x.days)
carry_exit['exit_TEM'] = CPI_EST
carry_exit['bond_price_in'] = carry_exit['c']
carry_exit['bond_price_out'] = (carry_exit['payoff'] / ((1+CPI_EST)**(carry_exit['days_to_exp']/30))).round(2)
carry_exit['ars_direct_yield'] = carry_exit['bond_price_out'] / carry_exit['bond_price_in'] - 1
carry_exit['ars_tea'] = carry_exit['ars_direct_yield'].add(1).pow(1/(carry_exit['days_in']/365)).sub(1)
carry_exit = carry_exit.sort_values('days_to_exp').loc[carry_exit.days_to_exp>0]

print(f"Estrategia en ARS (Assumption de compresion de tasa) saliendo el: {EST_DATE} a una TEM promedio del {CPI_EST:.2%}")
carry_exit[['days_to_exp','exit_TEM', 'days_in', 'bond_price_in', 'bond_price_out',  'ars_direct_yield' , 'ars_tea']].style \
    .background_gradient(subset=carry_exit.columns[-2:], cmap='Blues', axis=None) \
    .format({**{col: "{:.1%}" for col in carry_exit.columns[-2:]}, 'bond_price_in': "{:.2f}",  'bond_price_out': "{:.2f}",
             'ars_direct_yield': "{:.0%}", 'ars_tea': "{:.0%}", 'exit_TEM': "{:.2%}"})
# Out:
# Estrategia en ARS (Assumption de compresion de tasa) saliendo el: 2025-10-15 a una TEM promedio del 1.00%
# <style type="text/css">
# #T_8f085_row0_col5 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_8f085_row0_col6 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_8f085_row1_col5 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_8f085_row1_col6 {
#   background-color: #b3d3e8;
#   color: #000000;
# }
# #T_8f085_row2_col5 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_8f085_row2_col6 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_8f085_row3_col5 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_8f085_row3_col6 {
#   background-color: #97c6df;
#   color: #000000;
# }
# #T_8f085_row4_col5 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_8f085_row4_col6 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_8f085_row5_col5 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_8f085_row5_col6 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_8f085_row6_col5 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_8f085_row6_col6 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_8f085_row7_col5 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_8f085_row7_col6 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_8f085_row8_col5 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_8f085_row8_col6 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_8f085_row9_col5 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_8f085_row9_col6 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_8f085_row10_col5 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_8f085_row10_col6 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_8f085_row11_col5 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_8f085_row11_col6 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8f085" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8f085_level0_col0" class="col_heading level0 col0" >days_to_exp</th>
#       <th id="T_8f085_level0_col1" class="col_heading level0 col1" >exit_TEM</th>
#       <th id="T_8f085_level0_col2" class="col_heading level0 col2" >days_in</th>
#       <th id="T_8f085_level0_col3" class="col_heading level0 col3" >bond_price_in</th>
#       <th id="T_8f085_level0_col4" class="col_heading level0 col4" >bond_price_out</th>
#       <th id="T_8f085_level0_col5" class="col_heading level0 col5" >ars_direct_yield</th>
#       <th id="T_8f085_level0_col6" class="col_heading level0 col6" >ars_tea</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >symbol</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8f085_level0_row0" class="row_heading level0 row0" >S31O5</th>
#       <td id="T_8f085_row0_col0" class="data row0 col0" >16</td>
#       <td id="T_8f085_row0_col1" class="data row0 col1" >1.00%</td>
#       <td id="T_8f085_row0_col2" class="data row0 col2" >182</td>
#       <td id="T_8f085_row0_col3" class="data row0 col3" >114.80</td>
#       <td id="T_8f085_row0_col4" class="data row0 col4" >132.12</td>
#       <td id="T_8f085_row0_col5" class="data row0 col5" >15%</td>
#       <td id="T_8f085_row0_col6" class="data row0 col6" >33%</td>
#     </tr>
#     <tr>
#       <th id="T_8f085_level0_row1" class="row_heading level0 row1" >S10N5</th>
#       <td id="T_8f085_row1_col0" class="data row1 col0" >26</td>
#       <td id="T_8f085_row1_col1" class="data row1 col1" >1.00%</td>
#       <td id="T_8f085_row1_col2" class="data row1 col2" >182</td>
#       <td id="T_8f085_row1_col3" class="data row1 col3" >103.00</td>
#       <td id="T_8f085_row1_col4" class="data row1 col4" >121.20</td>
#       <td id="T_8f085_row1_col5" class="data row1 col5" >18%</td>
#       <td id="T_8f085_row1_col6" class="data row1 col6" >39%</td>
#     </tr>
#     <tr>
#       <th id="T_8f085_level0_row2" class="row_heading level0 row2" >S28N5</th>
#       <td id="T_8f085_row2_col0" class="data row2 col0" >44</td>
#       <td id="T_8f085_row2_col1" class="data row2 col1" >1.00%</td>
#       <td id="T_8f085_row2_col2" class="data row2 col2" >182</td>
#       <td id="T_8f085_row2_col3" class="data row2 col3" >102.95</td>
#       <td id="T_8f085_row2_col4" class="data row2 col4" >121.77</td>
#       <td id="T_8f085_row2_col5" class="data row2 col5" >18%</td>
#       <td id="T_8f085_row2_col6" class="data row2 col6" >40%</td>
#     </tr>
#     <tr>
#       <th id="T_8f085_level0_row3" class="row_heading level0 row3" >T15D5</th>
#       <td id="T_8f085_row3_col0" class="data row3 col0" >61</td>
#       <td id="T_8f085_row3_col1" class="data row3 col1" >1.00%</td>
#       <td id="T_8f085_row3_col2" class="data row3 col2" >182</td>
#       <td id="T_8f085_row3_col3" class="data row3 col3" >139.25</td>
#       <td id="T_8f085_row3_col4" class="data row3 col4" >167.42</td>
#       <td id="T_8f085_row3_col5" class="data row3 col5" >20%</td>
#       <td id="T_8f085_row3_col6" class="data row3 col6" >45%</td>
#     </tr>
#     <tr>
#       <th id="T_8f085_level0_row4" class="row_heading level0 row4" >T30E6</th>
#       <td id="T_8f085_row4_col0" class="data row4 col0" >107</td>
#       <td id="T_8f085_row4_col1" class="data row4 col1" >1.00%</td>
#       <td id="T_8f085_row4_col2" class="data row4 col2" >182</td>
#       <td id="T_8f085_row4_col3" class="data row4 col3" >113.65</td>
#       <td id="T_8f085_row4_col4" class="data row4 col4" >137.26</td>
#       <td id="T_8f085_row4_col5" class="data row4 col5" >21%</td>
#       <td id="T_8f085_row4_col6" class="data row4 col6" >46%</td>
#     </tr>
#     <tr>
#       <th id="T_8f085_level0_row5" class="row_heading level0 row5" >T13F6</th>
#       <td id="T_8f085_row5_col0" class="data row5 col0" >121</td>
#       <td id="T_8f085_row5_col1" class="data row5 col1" >1.00%</td>
#       <td id="T_8f085_row5_col2" class="data row5 col2" >182</td>
#       <td id="T_8f085_row5_col3" class="data row5 col3" >111.95</td>
#       <td id="T_8f085_row5_col4" class="data row5 col4" >139.26</td>
#       <td id="T_8f085_row5_col5" class="data row5 col5" >24%</td>
#       <td id="T_8f085_row5_col6" class="data row5 col6" >55%</td>
#     </tr>
#     <tr>
#       <th id="T_8f085_level0_row6" class="row_heading level0 row6" >TTM26</th>
#       <td id="T_8f085_row6_col0" class="data row6 col0" >152</td>
#       <td id="T_8f085_row6_col1" class="data row6 col1" >1.00%</td>
#       <td id="T_8f085_row6_col2" class="data row6 col2" >182</td>
#       <td id="T_8f085_row6_col3" class="data row6 col3" >104.70</td>
#       <td id="T_8f085_row6_col4" class="data row6 col4" >128.59</td>
#       <td id="T_8f085_row6_col5" class="data row6 col5" >23%</td>
#       <td id="T_8f085_row6_col6" class="data row6 col6" >51%</td>
#     </tr>
#     <tr>
#       <th id="T_8f085_level0_row7" class="row_heading level0 row7" >TTJ26</th>
#       <td id="T_8f085_row7_col0" class="data row7 col0" >258</td>
#       <td id="T_8f085_row7_col1" class="data row7 col1" >1.00%</td>
#       <td id="T_8f085_row7_col2" class="data row7 col2" >182</td>
#       <td id="T_8f085_row7_col3" class="data row7 col3" >103.50</td>
#       <td id="T_8f085_row7_col4" class="data row7 col4" >132.77</td>
#       <td id="T_8f085_row7_col5" class="data row7 col5" >28%</td>
#       <td id="T_8f085_row7_col6" class="data row7 col6" >65%</td>
#     </tr>
#     <tr>
#       <th id="T_8f085_level0_row8" class="row_heading level0 row8" >T30J6</th>
#       <td id="T_8f085_row8_col0" class="data row8 col0" >258</td>
#       <td id="T_8f085_row8_col1" class="data row8 col1" >1.00%</td>
#       <td id="T_8f085_row8_col2" class="data row8 col2" >182</td>
#       <td id="T_8f085_row8_col3" class="data row8 col3" >100.90</td>
#       <td id="T_8f085_row8_col4" class="data row8 col4" >133.01</td>
#       <td id="T_8f085_row8_col5" class="data row8 col5" >32%</td>
#       <td id="T_8f085_row8_col6" class="data row8 col6" >74%</td>
#     </tr>
#     <tr>
#       <th id="T_8f085_level0_row9" class="row_heading level0 row9" >TTS26</th

# %%
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)
def getDataV3(variableID):
    url = f"https://api.bcra.gob.ar/estadisticas/v3.0/Monetarias/{variableID}"
    r = requests.get(url, verify=False)
    return pd.DataFrame(r.json().get('results')).set_index('fecha')

tamar_tea = getDataV3(variableID=45)['valor']/100
tamar_tea.index = pd.to_datetime(tamar_tea.index)
tamar_tea = tamar_tea.sort_index()
tamar_tea = tamar_tea.loc[tamar_tea.index>'2025-01-15']
tamar_tem = ((1+tamar_tea)**(1/12)-1).to_frame().rename(columns={'valor': 'tamar_tem_spot'})
tamar_tem['tamar_tem_avg'] = tamar_tem.expanding().mean()
tamar_tem['TTM26'] = 0.0225
tamar_tem['TTJ26'] = 0.0219
tamar_tem['TTS26'] = 0.0217
tamar_tem['TTD26'] = 0.0214


plt.style.use('dark_background')
plt.rcParams.update({'font.size': 6})

fig, ax = plt.subplots(dpi=200, facecolor='black')


colores = {
    'tamar_tem_spot': 'white',
    'tamar_tem_avg': 'white',
    'TTM26': 'pink',
    'TTJ26': 'yellow',
    'TTS26': 'orange',
    'TTD26': 'gray'
}

for col in tamar_tem.columns:
    y = tamar_tem[col].dropna()
    if not y.empty:
        estilo = ':' if col == 'tamar_tem_spot' else '-'
        ax.plot(y.index, y.values, lw=0.5, color=colores[col], linestyle=estilo, label=col)
        ax.text(y.index[-1], y.iloc[-1], col, fontsize=5, va='center', ha='left', color=colores[col])

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.legend(frameon=False, ncol=3)
ax.grid(alpha=0.1)

ax.set_title("Tasa TAMAR (TEM desde 10 dias habiles pre duales) vs TEM Fija duales")
plt.show()
